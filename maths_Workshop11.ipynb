# %% [markdown]
# <a href="https://colab.research.google.com/github/ekataadhikari23/Maths/blob/main/maths_Workshop11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ekata Adhikari

# %% [markdown]
# ID : 2603789
